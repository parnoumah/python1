# %% [markdown]
# <a href="https://colab.research.google.com/github/parnoumah/python1/blob/main/exresice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("bonjour")
# Out:
# bonjour

# %% [markdown]
# (bonjour Parnou)

# %% [markdown]
# 1) Afficher “Bonjour”
# Objectif : afficher un texte.
# Étapes : ouvre un notebook → écris print("Bonjour") → exécute.
# Indice : print(...) affiche à l’écran.
# Exemple attendu : Bonjour

# %%
print("bonjour")
# Out:
# bonjour

# %% [markdown]
# 2) Afficher ton prénom
# Objectif : afficher ton prénom.
# Étapes : remplace “Alice” par ton prénom.
# Indice : guillemets pour du texte.
# Exemple : print("Haythem")

# %%
print("PARNEL")
# Out:
# PARNEL

# %% [markdown]
# Deux lignes d’affichage
# Objectif : afficher deux lignes.
#
# Étapes : deux print(...) l’un sous l’autre.
#
# Indice : chaque print fait une nouvelle ligne.
#
# Exemple :
#
# Bonjour
# Python

# %%
print("bonjour")
print("python")
# Out:
# bonjour
# python

# %%
print(bonjour)
print(python)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1756941818.py in <cell line: 0>()
# ----> 1 print(bonjour)
#       2 print(python)
#
# NameError: name 'bonjour' is not defined

# %%
print("bonjour")
print("python")
# Out:
# bonjour
# python

# %% [markdown]
# 4) Calcul simple
# Objectif : afficher 2 + 3.
# Étapes : print(2 + 3).
# Indice : pas de guillemets pour un nombre.
# Attendu : 5

# %%
print(2+3)
# Out:
# 5

# %% [markdown]
# 5) Texte + résultat
# Objectif : afficher 2+3= puis le résultat.
# Étapes : print("2+3=", 2+3).
# Indice : on peut passer plusieurs éléments à print.
# Attendu : 2+3= 5

# %%
print("2+3=",2+3)
# Out:
# 2+3= 5

# %% [markdown]
# 6) Variable nombre
# Objectif : créer une variable x=7 et l’afficher.
# Étapes : x = 7 puis print(x).
# Indice : = assigne une valeur.
# Attendu : 7

# %%
x = 7
print(x)
# Out:
# 7

# %% [markdown]
# 7) Variable texte
# Objectif : nom = "Nadia" puis afficher.
# Étapes : créer puis print(nom).
# Indice : guillemets pour le texte.
# Attendu : Nadia

# %%
print("parnel")
# Out:
# parnel

# %% [markdown]
# 8) Addition avec variables
# -Objectif : a=4, b=6, afficher a+b.
# -Étapes : créer, puis print(a+b).
# -Indice : variables numériques s’additionnent.
# -Attendu : 10

# %%
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1083478837.py in <cell line: 0>()
# ----> 1 print(a+b)
#
# NameError: name 'a' is not defined
